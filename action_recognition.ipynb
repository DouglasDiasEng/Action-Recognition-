# %% [markdown]
# <a href="https://colab.research.google.com/github/DouglasDiasEng/Action-Recognition-/blob/main/action_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import re
import os
import ssl
import cv2
import tempfile
from google.colab.patches import cv2_imshow
from urllib import request

# %%
url_classes = 'https://raw.githubusercontent.com/deepmind/kinetics-i3d/master/data/label_map.txt'
with request.urlopen(url_classes) as file:
  #print([row.decode('utf-8').strip() for row in file.readlines()])
  labels = ([row.decode('utf-8').strip() for row in file.readlines()])
  print(len(labels))
# Out:
# 400
